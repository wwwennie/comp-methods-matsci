# %% [markdown]
# ### PS3: Lattice Sums of non-perfect solids
#
# Pre-reqs:
# - jupyterlab-myst: https://github.com/executablebooks/jupyterlab-myst

# %% [markdown]
# ## Context and Motivations
#
# In the last problem set, we considered the properties of perfect cubic solids.
# We now consider the properties of non-perfect solids, e.g., solids with defects.
# We similarly need to find the minimum of energy with respect to not only the lattice parameters but also with respect to the atom positions in the vicinity of the defect.
#
# Consider a solid with a vacancy.
# We can create a vacancy by simply removing one of the atoms in our FCC supercell structure.
# All atoms around that vacancy will relax away from the equilibrium positions of the perfect solid.
# The change in energy between the system with the vacancy and the system without the vacancy is then the vacancy defect formation energy (excluding a chemical potential of the removed atom).
#
# Suppose we want to find the vacancy formation energy in a system with atoms that interact with the Lennard-Jones potential
#
# $\phi(r) = \frac{B}{r^{12}} - \frac{A}{r^6}$
#
# where the input is $r$ and the output is $\phi$. Often, the Lennard-Jones potential is written into a dimensionally more useful form that depends on two parameters: $\sigma$, which is the distance at which the potential is zero $\phi(\sigma) = 0$, and $\epsilon$, which is the absolute value of the minimum of the potential with units of energy.
# With these two parameters, the Lennard-Jones potential looks like
#
# $\phi(r) = 4\varepsilon\Big[ \Big(\frac{\sigma}{r}\Big)^{12} - \Big(\frac{\sigma}{r}\Big)^{6}\Big]$,
#
# where $\sigma = (B/A)^{1/6}$ and $\epsilon = A^2/4B$.
# The Lennard-Jones Potential is sometimes written in an equivalent form in terms of the position of the minimum $r_m$.
# One may easily derive that $r_m = 2^{1/6} \sigma$ and $\phi(r_m) = -\epsilon$ where $\epsilon$ corresponds to the well depth,
#
# $\phi(r) = \epsilon\Big[ \Big(\frac{r_m}{r}\Big)^{12} -2 \Big(\frac{r_m}{r}\Big)^6\Big]$.
#
# We need to set up a system from which we can remove the atom and then compare the energy of that system ($E_{vac}$) with the defect-free sysm ($E_{bulk}$).
# In the case of a vacancy in the FCC cell, the vacancy formation energy may be computed as
#
# $ \Delta U = E_{vac} - \frac{n-1}{n} E_{bulk} $
#
# where the chemical potential of the removed atom has been subsumed in the second term.
#
# We will use an FCC lattice with periodic boundary conditions.
# Because the system is periodic, introducing the vacancy will also create a vacancy in any periodic image leading to a vacancy concentration of $X_V = 1/n$ where $n$ is the number of atoms in the simulation cell.
# Clearly, the values of $X_V$ simulated are far larger than those found in real systems.
# To test whether we are simulating the dilute limit (i.e., isolated defects), we do a convergence test of the simulation cell size until the energy converges.
# More advanced methods can also be used, such as embedding the small system into an elastic continuum.

# %% [markdown]
# ## Exercises: cubic solids

# %% [markdown]
# 1. Using a Lennard-Jones potential with $\varepsilon = 0.3429$ eV and $r_m = 2.553$ Å, calculate the vacancy formation energy for Cu in the FCC structure. Assume the experimental lattice parameter and neglect any lattice relaxations. Use a cutoff distance $r_c$ equal to the distance to the third nearest neighbor. Look up an experimental value for the vacancy formation energy. How close if your result to the literature value? What are some reasons for the discrepancy between computed and experimental values?

# %%
# %pycat ./code_solns/PS3-1.py
# Out:
# import numpy as np
# import matplotlib.pyplot as plt
# from make_latt import fccmke
# from lat_sum import lat_sum1
#
# # Problem 1: Vacancy energy formation in FCC Cu
#
# # Lattice constant for Cu, from convergence, not experimental
# a0 = 3.533  # Angstrom
# a0s = np.arange(3.48, 3.7, 0.001)
# # Third nearest neighbor
# rc = np.ceil(a0 * np.sqrt(0.5**2 + 1**2) * 1.3)
# # Number of units per side
# nc = int(np.ceil(2 * rc / a0))
# # Length of the full lattice
# acell = a0 * nc
# # Number of atoms
# n = 4 * nc**3
#
# # Generate FCC lattice and calculate bulk energy
# sbulk, N = fccmke(nc)
# ucellbulk,timing = lat_sum1(a0, n, nc, rc, sbulk)
# print(f'Bulk energy (eV/atom): {ucellbulk} for {n} atom cell')
#
# # Calculate energy for different lattice constants
# ucells = []
# for i, a0i in enumerate(a0s):
#     ## progress bar
#     #print(f'{i / len(a0s) * 100}% done')
#     ucell1, timing = lat_sum1(a0i, n, nc, rc, sbulk)
#     ucells.append(ucell1)
#
# # Find minimum energy and lattice constant
# minucell = min(ucells)
# minindex = np.argmin(ucells)
# mina0 = a0s[minindex]
# print(f'Minimum Lattice Energy: {minucell}')
# print(f'Minimum Lattice Energy Lattice constant (Ang): {mina0}')
# print('----------------------------')
#
#
# # Make defect structure by removing an atom
# disps = np.sqrt((sbulk[:, 0] - 0.5)**2 + (sbulk[:, 1] - 0.5)**2 + (sbulk[:, 2] - 0.5)**2)
# rmatom = np.argmin(disps)
# svac = np.delete(sbulk, rmatom, axis=0)
#
# # Calculate vacancy energy
# ucellvac,timing = lat_sum1(a0, n - 1, nc, rc, svac)
# print(f'Vacancy Lattice Energy (eV/atom): {ucellvac} for {n - 1} atom cell')
#
# # Full cell vacancy formation energy
# ## convert eV/atom to eV
# ucellvac = ucellvac * (n - 1)
# ucellbulk = ucellbulk * n
# formation_energy = ucellvac - (n - 1) * ucellbulk / n
# print(f'Vacancy formation energy (eV): {formation_energy}')
#
# print('===================')
#
# # Plot the energy vs lattice constant
# plt.figure()
# plt.plot(a0s, ucells)
# plt.xlabel('Lattice constant (Angstroms)')
# plt.ylabel('Energy per atom (eV)')
# plt.show()
#
# ## Comparison with published literature
# ## experimental energy vacancy formation
# ## 0.9 +/- 0.05 eV http://www.sciencedirect.com/science/article/pii/0001616054901157
# ## C.J. Meechan and R.R. Eggleston. Formation energies of vacancies in gold
# ## and copper. Acta Metallurgica. Vol 2 Iss 5 (1954) 680-683.
# #
# ## 0.7 eV http://journals.aps.org/pr/abstract/10.1103/PhysRev.106.66
# ## P. Jongenburger. Energy of formation vacancies in Copper and Gold. Phys.
# ## Rev. 106,66 (1957)
# #
# ## 1.29 +/- 0.02
# ## W. Triftshäuser and J.D. McGervey. Monovacancy formation energy in copper, silver, and gold by positron annihilation. App. Phys. 6 (1975) 177

# %% [markdown]
# 2. Relax the atomic positions in the nearest shell of neighbors to the vacancy by varying the positions of the atoms until the energy is a minimum. How does the energy change? What direction do the atoms in the nearest shell move? How much does the energy change?

# %%
# %pycat ./code_solns/PS3-2.py
# Out:
# import numpy as np
# import matplotlib.pyplot as plt
# from make_latt import fccmke
# from lat_sum import lat_sum1
#
# # Problem 2: Relaxation in vacancy energy formation in FCC Cu
#
# # Initialize variables
# a0 = 3.533  # Angstrom, Cu lattice constant, from Problem 1
# rc = np.ceil(a0 * np.sqrt(0.5**2 + 1**2) * 1.3)  # third nearest neighbor
# nc = int(np.ceil(2 * rc / a0))  # number of units per side
# acell = a0 * nc  # length of the full lattice
# n = 4 * nc**3
#
# # Make FCC lattice, n x n x n
# s, il1 = fccmke(nc)
# ucellbulk,timing = lat_sum1(a0, n, nc, rc, s)
# print(f'Bulk Lattice Energy (eV/atom): {ucellbulk} for {nc} cell')
#
# # Make defect structure by removing an atom closest to the center
# disps = []
# for j in range(len(s)):
#     disps.append(np.sqrt((s[j, 0] - 0.5)**2 + (s[j, 1] - 0.5)**2 + (s[j, 2] - 0.5)**2))
#
# mindex = np.argsort(disps)
# svac = np.delete(s, mindex[0], axis=0)
#
# #---------------------------------------------------------
#
# ## No relaxation of formation energy vacancy
# ucellvac,timing = lat_sum1(a0, n - 1, nc, rc, svac)
# print(f'Vacancy Lattice Energy (eV/atom): {ucellvac} for 0.0000 disp')
# ucellvacfull = ucellvac * (n - 1)
# ucellbulkfull = ucellbulk * n
# formation_energy = ucellvacfull - (n - 1) * ucellbulkfull / n
# print(f'Vacancy formation energy (eV): {formation_energy} for 0.000 disp')
# print('----------------------')
#
#
# ## With manual relaxation for formation energy of vacancy
# # Recalibrate indices for proceeding operations
# dispswithvac = []
# for j in range(len(svac)):
#     dispswithvac.append(np.sqrt((svac[j, 0] - 0.5)**2 + (svac[j, 1] - 0.5)**2 + (svac[j, 2] - 0.5)**2))
#
# # With respect to vacancy coordinates, find 12 nearest neighbors from vacancy
# sortedindices = np.argsort(dispswithvac)
# nextnearest = sortedindices[:12]  # in FCC, twelve are nearest neighbors
# nearpos = svac[nextnearest, :]  # positions of next nearest neighbors to vacancy
#
# # Displace randomly 12 nearest neighbors; if lower energy, accept
# rmin = -0.05  # range of random displacement
# rmax = 0.05
# itermax = 1e4
# ucellvacprev = [ucellvac]
#
# # ---------------------------------------------------------
#
# ## Uniform displacement of atoms
# rdisp = np.linspace(rmin, rmax, 50)
# plotvac = []
# forme = []
#
# for i in range(len(rdisp)):
#     # Remove atoms being displaced
#     spartial = np.delete(svac, nextnearest, axis=0)
#     dispatoms = nearpos.copy()
#
#     # Expand or contract all atoms
#     # find which atoms are on which side of vacancy
#     #  otherwise, displacement would be rigid
#     #  shift of nearest neighbor shell
#     for m in range(len(nextnearest)):
#         # Shift to origin
#         xcoord = dispatoms[m, 0] - 0.5
#         ycoord = dispatoms[m, 1] - 0.5
#         zcoord = dispatoms[m, 2] - 0.5
#
#         # Conversion to spherical coordinates
#         r = np.sqrt(xcoord**2 + ycoord**2 + zcoord**2)
#         theta = np.arctan2(ycoord, xcoord)
#         phi = np.arccos(zcoord / r)
#
#         # Displacement
#         newr = r * (1 + rdisp[i])
#
#         # Conversion back to cartesian coordinates
#         newx = newr * np.cos(theta) * np.sin(phi)
#         newy = newr * np.sin(theta) * np.sin(phi)
#         newz = newr * np.cos(phi)
#
#         # Shift coordinates  back to vacancy as origin
#         dispatoms[m, 0] = newx + 0.5
#         dispatoms[m, 1] = newy + 0.5
#         dispatoms[m, 2] = newz + 0.5
#
#     # Handle degenerate coordinates
#     a, c = np.unique(dispatoms, axis=0, return_inverse=True)
#     tracker = np.column_stack((a, np.bincount(c)))
#
#     uniquedisp = []
#     for el in range(len(tracker)):
#         xcoord = tracker[el, 0] - 0.5
#         ycoord = tracker[el, 1] - 0.5
#         zcoord = tracker[el, 2] - 0.5
#         if tracker[el, -1] > 1:  # If coordinate is non-unique
#             reflect = np.array([[-1, 0, 0], [0, -1, 0], [0, 0, -1]])  # Reflection about origin
#             pseudor = reflect @ np.array([xcoord, ycoord, zcoord])
#
#             reflection = pseudor + 0.5
#
#             uniquedisp.append(tracker[el, 0:3])  # Add once
#             uniquedisp.append(reflection)  # Add its reflection
#         else:
#             uniquedisp.append(tracker[el, 0:3])
#
#     svacdisp = np.vstack((spartial, uniquedisp))
#     ucellvacdisp,timing = lat_sum1(a0, n - 1, nc, rc, svacdisp)
#
#     # compute vacancy formation energy for a particular displacement
#     print(f'Vacancy Formation Energy (eV): {ucellvacdisp}')
#     # and save for plotting purposes
#     plotvac.append(ucellvacdisp)
#
#     ucellvacfull = ucellvacdisp * (n - 1)  # eV/atom -> eV
#     ucellbulkfull = ucellbulk * n
#     forme.append(ucellvacfull - (n - 1) * ucellbulkfull / n)
#
#
# ### Summary of computed results
# print('-------------------------------')
# print(f'Min Formation energy (eV): {min(forme)}')
# vacmin = min(plotvac)
# indexmin = np.argmin(plotvac)
# print(f'Vacancy Relax E_min displacement (eV): {rdisp[indexmin]}')
# print(f'Vacancy Relax E_min (eV): {vacmin * (n - 1)} for system and {vacmin} per atom')
# print(f'Vacancy Energy changed by (eV): {(vacmin - ucellvac) * (n - 1)}')
# print('===============================')
#
# # Plot the results
# plt.plot(rdisp, plotvac)
# plt.xlabel('Generalized displacement coordinate (Angstrom)')
# plt.ylabel('Energy per atom (eV)')
# plt.show()

# %% [markdown]
# ## Exercises: non-cubic solids

# %% [markdown]
# Suppose we want to model a system that is not a cubic structure.
# As outlined in the textbook, we can write the atomic positions in fractions of the unit cell as done before.
# The distance between two atoms with indices $i$ and $j$ in the full, non-cubic cell is
#
# $r_{ij}^2 = \vec{s}_{ij}^T \mathbf{G} \vec{s}_{ij} = \vec{s}_{ij} \cdot (\mathbf{G} \vec{s}_{ij})$
#
# where $\vec{s}_{ij} = \vec{s}_j - \vec{s}_i$ and $\mathbf{G}$ is the metric tensor
#
# $\mathbf{G} = \begin{pmatrix}
# a^2 & ab\cos(\gamma) & ac\cos(\beta) \\
# ab\cos(\gamma) & b^2 & bc\cos(\alpha) \\
# ac\cos(\beta) & bc\cos(\alpha) & c^2
# \end{pmatrix}
# $
#
# where $a,b,c,\alpha,\beta,\gamma$ are the standard lattice constants.
#
# We can evaluate the distance between two atoms $r_{ij}$ as follows.
# Suppose we consider a vector $\vec{t} = (t_1,t_2,t_3)$ and a $3\times 3$ matrix $\mathbf{G}$, we have
#
# $\vec{t}^T \mathbf{G} \vec{t} = \vec{t} \cdot (\mathbf{G} \vec{t}) = t_i \cdot G_{ij} t_j)$
#
# where repeated indices are summed.
# As $\mathbf{G}$ is a symmetric matrix, $G_{ij} = G_{ji}$, we can explicitly evaluate the above terms.
#
# $\vec{t}^T \mathbf{G} \vec{t} =  G_{11} t^2 + G_{22} t_2^2 + 2G_{12}t_1 t_2  + 2 G_{13} t_1 t_3 + 2G_{23} t_2 t_3
# =  a^2 t_1^2 + b^2 t_2^2 + c^2 t_3^2 + 2ab\cos(\gamma)t_1 t_2 + 2ac\cos(\beta)t_1 t_3 + 2bc\cos(\alpha)t_2 t_3
# $
#
# Thus, in order to evaluate the distances between atoms $r_{ij}$, we replace
# ```dist = a * sqrt(xij^2 + yij^2 + zij^2);```
# with
# ```
# dist = sqrt(a**2*xij^2 + b**2*yij^2 + c**2*zij^2
#          + 2.*a*b*cos(gamma)*xij*yij
#          + 2.*a*c*cos(beta)*xij*zij
#          + 2.*b*c*cos(alpha)*yij*zij);
# ```

# %% [markdown]
# 3. Rewrite the codes from Part 1 for evaluating the energy of a non-cubic lattice. Assuming the same scaled positions as in an FCC lattice, evaluate the energy as a function of $a,b,c$ while keeping the lattice angles 90$^o$. Which structure is more stable, the cubic or a non-cubic structure in which the lattice parameters are allowed to vary?

# %%
## note: will take a some time to run in search across lattice parameters b and c
# %pycat ./code_solns/PS3-3.py
# Out:
# import numpy as np
# import matplotlib.pyplot as plt
# from make_latt import fccmke
# from lat_sum import lat_sum2
#
# # Problem 3: Non-cubic cell
#
# # Initialize variables
# a0 = 3.6149  # Angstrom, experimental lattice constant
# nc = 4
# rc = a0 * nc / 2  # cutoff distance
# n = 4 * nc**3  # number of atoms
# volume = (nc * a0)**3
#
# # Generate FCC lattice
# s, il1 = fccmke(nc)
#
# # Cubic cell energy calculation
# ucellcub,timing = lat_sum2(a0 * nc, a0 * nc, a0 * nc, 90, 90, 90, n, rc, nc, s)
# print(f'Cubic Energy: {ucellcub} for {nc} cell')
#
# # Non-cubic cell parameters, holding the volume constant
# granularity = 20
# bs = np.linspace(2, 8, granularity)
# cs = 1 / bs * volume / (nc**3 * a0)
#
# ucells = []
# error = 0.1
# for i in range(len(bs)):
#     if abs(volume - a0 * bs[i] * cs[i] * nc**3) < error:
#         ucell2,timing = lat_sum2(a0 * nc, bs[i] * nc, cs[i] * nc, 90, 90, 90, n, rc, nc, s)
#         ucells.append(ucell2)
#     else:
#         print('Not preserving volume!')
#         break
#
# # Plotting results for b lattice constant
# plt.figure()
# plt.plot(bs, ucells, label='Non-cubic')
# plt.plot(bs, [ucellcub] * len(bs), label='Cubic')
# plt.xlabel('b Lattice constant (Angstroms)')
# plt.ylabel('Energy per atom (eV)')
# plt.legend()
#
# # Plotting results for c lattice constant
# plt.figure()
# plt.plot(cs, ucells, label='Non-cubic')
# plt.plot(cs, [ucellcub] * len(bs), label='Cubic')
# plt.xlabel('c Lattice constant (Angstroms)')
# plt.ylabel('Energy per atom (eV)')
# plt.legend()
#
# plt.show()

# %% [markdown]
# 4. A very well-known transition called the Bain transition involves the transformation of a BCC lattice to an FCC lattice, and vice versa. While these two structures seem different at face value, one may relate the BCC structure to the FCC structure via a simple path. Namely, the BCC structure can be described as a face-centered tetragonal (FCT) structure with specific relations between the lattice parameters. In the FCT structure, the lattice positions (in fractional coordinates) are the same as those in the FCC structure, as illustrated in the figure below. If we set $a = \sqrt(2)c$ in the FCT structure, then it becomes a BCC structure. You can show this by evaluating the energy for an FCT structure with $a = \sqrt(2)c$ and the same volume per atom as found in Problem 4 of Part 1. Do you find the same lattice energy (assuming the same cutoff distances)?
#
# ```{figure} ./figs/fcc-to-bcc-bain.png
# :name: diffusion
# :alt: Diffusion barrier
# :align: center
# :width: 300 px
#
# Bain transition from FCC to BCC.

# %%
# %pycat ./code_solns/PS3-4.py
# Out:
# import numpy as np
# from make_latt import fccmke,bccmke
# from lat_sum import lat_sum2
#
#
# # Problem 4: Bain Transformation
#
# nc = 3
#
# # BCC parameters
# a0bcc = 1.235
# nbcc = 2 * nc**3  # number of atoms
# sbcc, il1 = bccmke(nc)
# rc = a0bcc * nc /2 # cutoff distance, same for fcc cell
#
# ucellbcc,timing = lat_sum2(a0bcc * nc, a0bcc * nc, a0bcc * nc, 90, 90, 90, nbcc, rc, nc, sbcc)
# print(f'BCC Energy: {ucellbcc} for {nc} cell')
# print(f'BCC vol/atom: {a0bcc**3 / 2}')
#
# # FCC parameters
# fctvol = 2 * np.sqrt(2) * a0bcc**3  # sort of volume, off by factor sqrt(2)
# a0fcc = fctvol**(1/3)  # same volume per atom in BCC
# c = a0fcc / np.sqrt(2)
#
# nfct = 4 * nc**3  # number of atoms
# sfct, il1 = fccmke(nc)
#
# ucellfct,timing = lat_sum2(a0fcc * nc, a0fcc * nc, c * nc, 90, 90, 90, nfct, rc, nc, sfct)
# print(f'FCT Energy: {ucellfct} for {nc} cell')
# print(f'FCT vol/atom: {fctvol / (4 * np.sqrt(2))}')
# print('----------------------------')
#
# # Example output for different n values
# # n = 5
# # BCC Energy: -7.948672 for 5 cell
# # BCC vol/atom: 0.941826
# # FCT Energy: -7.948672 for 5 cell
# # FCT vol/atom: 0.941826
# # ----------------------------
#
# # n = 3
# # BCC Energy: -6.792686 for 3 cell
# # BCC vol/atom: 0.941826
# # FCT Energy: -6.792686 for 3 cell
# # FCT vol/atom: 0.941826
# # ----------------------------

# %% [markdown]
# ##  =================== Solution Report Sample ============================

# %%
from IPython.display import IFrame
IFrame('./PS3-solutions-writeup.pdf', width=700, height=600)
# Out:
#         <iframe
#             width="700"
#             height="600"
#             src="./PS3-solutions-writeup.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
